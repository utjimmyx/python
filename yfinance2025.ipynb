# %% [markdown]
# <a href="https://colab.research.google.com/github/utjimmyx/python/blob/main/yfinance2025.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import yfinance as yf
import pandas as pd

# %%
ticker = yf.Ticker("AAPL")

# %%
ticker.info
# Out:
# {'address1': 'One Apple Park Way',
#  'city': 'Cupertino',
#  'state': 'CA',
#  'zip': '95014',
#  'country': 'United States',
#  'phone': '(408) 996-1010',
#  'website': 'https://www.apple.com',
#  'industry': 'Consumer Electronics',
#  'industryKey': 'consumer-electronics',
#  'industryDisp': 'Consumer Electronics',
#  'sector': 'Technology',
#  'sectorKey': 'technology',
#  'sectorDisp': 'Technology',
# ...

# %%
ticker.history()
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2024-12-04 00:00:00-05:00  242.869995  244.110001  241.250000  243.009995
# 2024-12-05 00:00:00-05:00  243.990005  244.539993  242.130005  243.039993
# 2024-12-06 00:00:00-05:00  242.910004  244.630005  242.080002  242.839996
# 2024-12-09 00:00:00-05:00  241.830002  247.240005  241.750000  246.750000
# 2024-12-10 00:00:00-05:00  246.889999  248.210007  245.339996  247.770004
# 2024-12-11 00:00:00-05:00  247.960007  250.800003  246.259995  246.490005
# 2024-12-12 00:00:00-05:00  246.889999  248.740005  245.679993  247.960007
# 2024-12-13 00:00:00-05:00  247.820007  249.289993  246.240005  248.130005
# 2024-12-16 00:00:00-05:00  247.990005  251.380005  247.649994  251.039993
# 2024-12-17 00:00:00-05:00  250.080002  253.830002  249.779999  253.479996
# 2024-12-18 00:00:00-05:00  252.160004  254.279999  247.740005  248.050003
# 2024-12-19 00:00:00-05:00  247.500000  252.000000  247.089996  249.789993
# ...

# %%
ticker.history(period="max")
# Out:
#                                  Open        High         Low       Close  \
# Date
# 1980-12-12 00:00:00-05:00    0.098834    0.099264    0.098834    0.098834
# 1980-12-15 00:00:00-05:00    0.094108    0.094108    0.093678    0.093678
# 1980-12-16 00:00:00-05:00    0.087232    0.087232    0.086802    0.086802
# 1980-12-17 00:00:00-05:00    0.088951    0.089381    0.088951    0.088951
# 1980-12-18 00:00:00-05:00    0.091530    0.091959    0.091530    0.091530
# ...                               ...         ...         ...         ...
# 2024-12-27 00:00:00-05:00  257.829987  258.700012  253.059998  255.589996
# 2024-12-30 00:00:00-05:00  252.229996  253.500000  250.750000  252.199997
# 2024-12-31 00:00:00-05:00  252.440002  253.279999  249.429993  250.419998
# 2025-01-02 00:00:00-05:00  248.929993  249.100006  241.820007  243.850006
# 2025-01-03 00:00:00-05:00  243.360001  244.179993  241.889999  243.360001
#
#                               Volume  Dividends  Stock Splits
# Date
# ...

# %%
balance_sheet = ticker.balance_sheet

# %%
print(balance_sheet)
# Out:
#                                                       2024-09-30  \
# Treasury Shares Number                                       NaN
# Ordinary Shares Number                             15116786000.0
# Share Issued                                       15116786000.0
# Net Debt                                           76686000000.0
# Total Debt                                        106629000000.0
# ...                                                          ...
# Cash Cash Equivalents And Short Term Investments   65171000000.0
# Other Short Term Investments                       35228000000.0
# Cash And Cash Equivalents                          29943000000.0
# Cash Equivalents                                    2744000000.0
# Cash Financial                                     27199000000.0
#
#                                                       2023-09-30  \
# Treasury Shares Number                                       0.0
# ...

# %%
income_statement = ticker.income_stmt

# %%
print(income_statement)
# Out:
#                                                         2024-09-30  \
# Tax Effect Of Unusual Items                                    0.0
# Tax Rate For Calcs                                        0.240912
# Normalized EBITDA                                   134661000000.0
# Net Income From Continuing Operation Net Minori...   93736000000.0
# Reconciled Depreciation                              11445000000.0
# Reconciled Cost Of Revenue                          210352000000.0
# EBITDA                                              134661000000.0
# EBIT                                                123216000000.0
# Net Interest Income                                            NaN
# Interest Expense                                               NaN
# Interest Income                                                NaN
# Normalized Income                                    93736000000.0
# Net Income From Continuing And Discontinued Ope...   93736000000.0
# ...

# %%
cash_flow = ticker.cashflow
print(cash_flow)
# Out:
#                                                     2024-09-30  \
# Free Cash Flow                                  108807000000.0
# Repurchase Of Capital Stock                     -94949000000.0
# Repayment Of Debt                                -9958000000.0
# Issuance Of Debt                                           0.0
# Issuance Of Capital Stock                                  NaN
# Capital Expenditure                              -9447000000.0
# Interest Paid Supplemental Data                            NaN
# Income Tax Paid Supplemental Data                26102000000.0
# End Cash Position                                29943000000.0
# Beginning Cash Position                          30737000000.0
# Changes In Cash                                   -794000000.0
# Financing Cash Flow                            -121983000000.0
# Cash Flow From Continuing Financing Activities -121983000000.0
# Net Other Financing Charges                      -5802000000.0
# ...

# %%
with pd.ExcelWriter("AAPL.xlsx") as writer:
    balance_sheet.to_excel(writer, sheet_name="Balance Sheet")
    income_statement.to_excel(writer, sheet_name="Income Statement")
    cash_flow.to_excel(writer, sheet_name="Cash Flow")

# %%
ticker.eps_trend
# Out:
#      current  7daysAgo  30daysAgo  60daysAgo  90daysAgo
# 0q   2.34897   2.35100    2.34977    2.35230    2.38261
# +1q  1.67928   1.67860    1.68095    1.68125    1.70681
# 0y   7.38751   7.38756    7.38754    7.37191    7.40367
# +1y  8.27612   8.27620    8.26639    8.24251    8.31647
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_16['current'].plot(kind='hist', bins=20, title='current')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_17['7daysAgo'].plot(kind='hist', bins=20, title='7daysAgo')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_18['30daysAgo'].plot(kind='hist', bins=20, title='30daysAgo')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# ...

# %%
ticker.dividends
# Out:
# Date
# 1987-05-11 00:00:00-04:00    0.000536
# 1987-08-10 00:00:00-04:00    0.000536
# 1987-11-17 00:00:00-05:00    0.000714
# 1988-02-12 00:00:00-05:00    0.000714
# 1988-05-16 00:00:00-04:00    0.000714
#                                ...
# 2023-11-10 00:00:00-05:00    0.240000
# 2024-02-09 00:00:00-05:00    0.240000
# 2024-05-10 00:00:00-04:00    0.250000
# 2024-08-12 00:00:00-04:00    0.250000
# 2024-11-08 00:00:00-05:00    0.250000
# Name: Dividends, Length: 85, dtype: float64
